# %% [markdown]
# # Importing modules

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab

# %%
nypd=pd.read_csv("F:/python/csv/nypd_all_data.csv")

# %%
nypd
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                               PD_DESC  \
# 0         173130602  12/31/2017  566.0                 MARIJUANA, POSSESSION
# 1         173114463  12/31/2017  478.0       THEFT OF SERVICES, UNCLASSIFIED
# 2         173113513  12/31/2017  849.0  NY STATE LAWS,UNCLASSIFIED VIOLATION
# 3         173113423  12/31/2017  101.0                             ASSAULT 3
# 4         173113421  12/31/2017  101.0                             ASSAULT 3
# ...             ...         ...    ...                                   ...
# 4798334   173142136  01/01/2018  639.0               AGGRAVATED HARASSMENT 2
# 4798335   173135232  01/01/2018  109.0              ASSAULT 2,1,UNCLASSIFIED
# 4798336   173134328  01/01/2018  397.0       ROBBERY,UNCLASSIFIED,OPEN AREAS
# 4798337   173134322  01/01/2018  922.0        TRAFFIC,UNCLASSIFIED MISDEMEAN
# 4798338   173130592  01/01/2018  109.0              ASSAULT 2,1,UNCLASSIFIED
#
# ...

# %% [markdown]
# # Length of file

# %%
len(nypd)
# Out:
# 4798339

# %% [markdown]
# # Filling na values with 0

# %%
nypd=nypd.fillna(0)

# %% [markdown]
# # Replacing 0 with NAN

# %%
import numpy as np
nypd=nypd.replace(['0',' ' ,'-'],np.NAN)

# %%
nypd_empty=nypd.isnull().values.any()
nypd_empty
# Out:
# True

# %%
nypd_empty=nypd.isnull()
nypd_empty
# Out:
#          ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# 0             False        False  False    False  False      False     False
# 1             False        False  False    False  False      False     False
# 2             False        False  False    False  False      False     False
# 3             False        False  False    False  False      False     False
# 4             False        False  False    False  False      False     False
# ...             ...          ...    ...      ...    ...        ...       ...
# 4798334       False        False  False    False  False      False     False
# 4798335       False        False  False    False  False      False     False
# 4798336       False        False  False    False  False      False     False
# 4798337       False        False  False    False  False      False     False
# 4798338       False        False  False    False  False      False     False
#
# ...

# %%
nypd
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                               PD_DESC  \
# 0         173130602  12/31/2017  566.0                 MARIJUANA, POSSESSION
# 1         173114463  12/31/2017  478.0       THEFT OF SERVICES, UNCLASSIFIED
# 2         173113513  12/31/2017  849.0  NY STATE LAWS,UNCLASSIFIED VIOLATION
# 3         173113423  12/31/2017  101.0                             ASSAULT 3
# 4         173113421  12/31/2017  101.0                             ASSAULT 3
# ...             ...         ...    ...                                   ...
# 4798334   173142136  01/01/2018  639.0               AGGRAVATED HARASSMENT 2
# 4798335   173135232  01/01/2018  109.0              ASSAULT 2,1,UNCLASSIFIED
# 4798336   173134328  01/01/2018  397.0       ROBBERY,UNCLASSIFIED,OPEN AREAS
# 4798337   173134322  01/01/2018  922.0        TRAFFIC,UNCLASSIFIED MISDEMEAN
# 4798338   173130592  01/01/2018  109.0              ASSAULT 2,1,UNCLASSIFIED
#
# ...

# %% [markdown]
# # Grouping by

# %%
grouping=nypd.groupby('PD_DESC')
grouping

# %%
assault=grouping.get_group('ASSAULT 3' )
assault
# Out:
#          ARREST_KEY ARREST_DATE  PD_C
# 4        12/31/2017                             ASSAULT 3
# ...             ...                                   ...
# 4798334  01/01/2018               AGGRAVATED HARASSMENT 2
# 4798335  01/01/2018              ASSAULT 2,1,UNCLASSIFIED
# 4798336  01/01/2018       ROBBERY,UNCLASSIFIED,OPEN AREAS
# 4798337  01/01/2018        TRAFFIC,UNCLASSIFIED MISDEMEAN
# 4798338  01/01/2018              ASSAULT 2,1,UNCLASSIFIED
#
#                                            OFNS_DESC  JURISDICTION_CODE  \
# 0                            MISCELLANEOUS PENAL LAW                NaN
# 1                    OTHER OFFENSES RELATED TO THEFT                NaN
# ...

# %%
group_by_date=Drp.groupby('ARREST_DATE')

# %%
group_by_date.get_group('12/31/2017')
# Out:
#     ARREST_DATE                                    PD_DESC  \
# 0    12/31/2017                      MARIJUANA, POSSESSION
# 1    12/31/2017            THEFT OF SERVICES, UNCLASSIFIED
# 2    12/31/2017       NY STATE LAWS,UNCLASSIFIED VIOLATION
# 3    12/31/2017                                  ASSAULT 3
# 4    12/31/2017                                  ASSAULT 3
# ..          ...                                        ...
# 348  12/31/2017                MARIJUANA, POSSESSION 4 & 5
# 349  12/31/2017                                  ASSAULT 3
# 350  12/31/2017  PUBLIC ADMINISTRATION,UNCLASSIFIED FELONY
# 351  12/31/2017                          STRANGULATION 1ST
# 352  12/31/2017                   WEAPONS, POSSESSION, ETC
#
#                            OFNS_DESC  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0            MISCELLANEOUS PENAL LAW                NaN     25-44        M
# 1    OTHER OFFENSES RELATED TO THEFT                NaN     25-44        M
# ...

# %%
grp_by_sex=Drp.groupby('PERP_SEX')

# %%
grp_by_sex

# %%
grp_by_sex.get_group('M')
# Out:
#         ARREST_DATE                                     PD_DESC  \
# 0        12/31/2017                       MARIJUANA, POSSESSION
# 1        12/31/2017             THEFT OF SERVICES, UNCLASSIFIED
# 2        12/31/2017        NY STATE LAWS,UNCLASSIFIED VIOLATION
# 3        12/31/2017                                   ASSAULT 3
# 4        12/31/2017                                   ASSAULT 3
# ...             ...                                         ...
# 4798333  01/01/2018  LARCENY,PETIT FROM OPEN AREAS,UNCLASSIFIED
# 4798335  01/01/2018                    ASSAULT 2,1,UNCLASSIFIED
# 4798336  01/01/2018             ROBBERY,UNCLASSIFIED,OPEN AREAS
# 4798337  01/01/2018              TRAFFIC,UNCLASSIFIED MISDEMEAN
# 4798338  01/01/2018                    ASSAULT 2,1,UNCLASSIFIED
#
#                                OFNS_DESC  JURISDICTION_CODE AGE_GROUP  \
# 0                MISCELLANEOUS PENAL LAW                NaN     25-44
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Drp.to_csv('file1.csv')
